# %%
# Importando bibliotecas.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Ler excel do repositório.
df = pd.read_csv("../data/raw/doencas_cardiacas.csv")

# %%
# Mudando nome de colunas.
df.rename(columns = {"age":"idade", "sex":"sexo", "chest pain type":"tipo de dor de peito", "resting bp s": "batimento por segundo em repouso", "cholesterol":"colesterol", "fasting blood sugar":"açucar no sangue em jejum", "resting ecg":"ECG em repouso", "max heart rate":"taxa de batimentos máximo", "exercise angina":"angina em exercício", "oldpeak":"depressão do segmento ST", "ST slope":"inclinação do segmento ST", "target":"alvo"}, inplace = True)

# Substituindo valores.
df['sexo'].replace({1: 'homem', 0: 'mulher'}, inplace = True)
df['tipo de dor de peito'].replace({1: 'angina típica (clássica)', 2:'angina atípica', 3:'dor não-anginosa', 4:'assintomático'}, inplace = True)
df['açucar no sangue em jejum'].replace({0: 'não', 1: 'sim'}, inplace = True)
df['ECG em repouso'].replace({0: 'normal', 1: ' anormalidade de onda ST-T', 2: 'hipertrofia ventricular esquerda provável (LVH)'}, inplace = True)
df['angina em exercício'].replace({0: 'não', 1: 'sim'}, inplace = True)
df['inclinação do segmento ST'].replace({1: 'cima', 2: 'plano', 3: 'baixo'}, inplace = True)
df['alvo'].replace({1: 'cardíaco', 0: 'não cardíaco'}, inplace = True)

# Informações gerais do DataFrame.
print("\nInformações do DataFrame:")
df.info()

# Contagem de valores ausentes
print("\nValores ausentes em cada coluna:")
df.isnull().sum()
# Out:
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   idade                             1190 non-null   int64
#  1   sexo                              1190 non-null   object
#  2   tipo de dor de peito              1190 non-null   object
#  3   batimento por segundo em repouso  1190 non-null   int64
#  4   colesterol                        1190 non-null   int64
#  5   açucar no sangue em jejum         1190 non-null   object
#  6   ECG em repouso                    1190 non-null   object
#  7   taxa de batimentos máximo         1190 non-null   int64
#  8   angina em exercício               1190 non-null   object
#  9   depressão do segmento ST          1190 non-null   float64
#  10  inclinação do segmento ST         1190 non-null   object
#  11  alvo                              1190 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 111.7+ KB
#
# Valores ausentes em cada coluna:
# idade                               0
# sexo                                0
# tipo de dor de peito                0
# batimento por segundo em repouso    0
# colesterol                          0
# açucar no sangue em jejum           0
# ECG em repouso                      0
# taxa de batimentos máximo           0
# angina em exercício                 0
# depressão do segmento ST            0
# inclinação do segmento ST           0
# alvo                                0
# dtype: int64

# %%
# Prints de visualização do DataFrame.
print('Primeiras linhas:\n')
display(df.head())
print("\nÚltimas linhas:\n")
display(df.tail())
print("\nNúmero total de linhas e colunas:")
display(df.shape)

# Resumo estatístico de colunas numéricas.
display(df.describe())
# Out:
# Primeiras linhas:
#    idade    sexo tipo de dor de peito  batimento por segundo em repouso  \
# 0     40   homem       angina atípica                               140
# 1     49  mulher     dor não-anginosa                               160
# 2     37   homem       angina atípica                               130
# 3     48  mulher        assintomático                               138
# 4     54   homem     dor não-anginosa                               150
#
#    colesterol açucar no sangue em jejum              ECG em repouso  \
# 0         289                       não                      normal
# 1         180                       não                      normal
# 2         283                       não   anormalidade de onda ST-T
# 3         214                       não                      normal
# 4         195                       não                      normal
#
#    taxa de batimentos máximo angina em exercício  depressão do segmento ST  \
# 0                        172                 não                       0.0
# 1                        156                 não                       1.0
# 2                         98                 não                       0.0
# 3                        108                 sim                       1.5
# 4                        122                 não                       0.0
#
#   inclinação do segmento ST          alvo
# 0                      cima  não cardíaco
# 1                     plano      cardíaco
# 2                      cima  não cardíaco
# 3                     plano      cardíaco
# 4                      cima  não cardíaco
# Últimas linhas:
#       idade    sexo      tipo de dor de peito  \
# 1185     45   homem  angina típica (clássica)
# 1186     68   homem             assintomático
# 1187     57   homem             assintomático
# 1188     57  mulher            angina atípica
# 1189     38   homem          dor não-anginosa
#
#       batimento por segundo em repouso  colesterol açucar no sangue em jejum  \
# 1185                               110         264                       não
# 1186                               144         193                       sim
# 1187                               130         131                       não
# 1188                               130         236                       não
# 1189                               138         175                       não
#
#                                        ECG em repouso  \
# 1185                                           normal
# 1186                                           normal
# 1187                                           normal
# 1188  hipertrofia ventricular esquerda provável (LVH)
# 1189                                           normal
#
#       taxa de batimentos máximo angina em exercício  depressão do segmento ST  \
# 1185                        132                 não                       1.2
# 1186                        141                 não                       3.4
# 1187                        115                 sim                       1.2
# 1188                        174                 não                       0.0
# 1189                        173                 não                       0.0
#
#      inclinação do segmento ST          alvo
# 1185                     plano      cardíaco
# 1186                     plano      cardíaco
# 1187                     plano      cardíaco
# 1188                     plano      cardíaco
# 1189                      cima  não cardíaco
# Número total de linhas e colunas:
# (1190, 12)
#              idade  batimento por segundo em repouso   colesterol  \
# count  1190.000000                       1190.000000  1190.000000
# mean     53.720168                        132.153782   210.363866
# std       9.358203                         18.368823   101.420489
# min      28.000000                          0.000000     0.000000
# 25%      47.000000                        120.000000   188.000000
# 50%      54.000000                        130.000000   229.000000
# 75%      60.000000                        140.000000   269.750000
# max      77.000000                        200.000000   603.000000
#
#        taxa de batimentos máximo  depressão do segmento ST
# count                1190.000000               1190.000000
# mean                  139.732773                  0.922773
# std                    25.517636                  1.086337
# min                    60.000000                 -2.600000
# 25%                   121.000000                  0.000000
# 50%                   140.500000                  0.600000
# 75%                   160.000000                  1.600000
# max                   202.000000                  6.200000
